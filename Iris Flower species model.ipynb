# %% [markdown]
# # TASK 1 - IRIS FLOWER CLASSIFICATION
#
# Problem Statement:
#
# Iris flower has three species: setosa, versicolor, and virginica, which differs according to their measurements. Now assume that you have the measurements of the iris flowers according to their species, and here your task is to train a machine learning model that can learn from the measurements of the iris species and classify them.

# %% [markdown]
# # Solution:
#
# Importing the necessary libraries and displaying head

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.shape
# Out:
# (150, 6)

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
#Displaying the number of records in each class

df['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %% [markdown]
# # Preprocessing the dataset

# %%
#Checking for null values

df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
#map function
#to convert characters into numbers

df['Species1']=df['Species'].map({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  Species1
# 0       Iris-setosa         0
# 1       Iris-setosa         0
# 2       Iris-setosa         0
# 3       Iris-setosa         0
# 4       Iris-setosa         0
# ..              ...       ...
# 145  Iris-virginica         2
# 146  Iris-virginica         2
# 147  Iris-virginica         2
# 148  Iris-virginica         2
# 149  Iris-virginica         2
#
# [150 rows x 7 columns]

# %% [markdown]
# # Data Analysis

# %%
# Histogram

df['SepalLengthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
df['SepalWidthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
df['PetalLengthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
df['PetalWidthCm'].hist()
# Out:
# <AxesSubplot:>

# %%
# Scatterplot

colors = ['green','orange','blue',]
species = ['Iris-setosa','Iris-versicolor','Iris-virginica']

# %%
for i in range(3):
    x = df[df['Species'] == species[i]]
    plt.scatter(x['SepalLengthCm'], x['SepalWidthCm'], c = colors[i], label = species[i])
    plt.xlabel("Sepal Length")
    plt.ylabel("Sepal Width")
    plt.legend()

# %%
for i in range(3):
    x = df[df['Species'] == species[i]]
    plt.scatter(x['PetalLengthCm'], x['PetalWidthCm'], c = colors[i], label = species[i])
    plt.xlabel("Petal Length")
    plt.ylabel("Petal Width")
    plt.legend()

# %%
for i in range(3):
    x = df[df['Species'] == species[i]]
    plt.scatter(x['SepalLengthCm'], x['PetalLengthCm'], c = colors[i], label = species[i])
    plt.xlabel("Sepal Length")
    plt.ylabel("Petal Length")
    plt.legend()

# %%
for i in range(3):
    x = df[df['Species'] == species[i]]
    plt.scatter(x['SepalWidthCm'], x['PetalWidthCm'], c = colors[i], label = species[i])
    plt.xlabel("Sepal Width")
    plt.ylabel("Petal Width")
    plt.legend()

# %%
for i in range(3):
    x = df[df['Species'] == species[i]]
    plt.scatter(x['PetalWidthCm'], x['SepalLengthCm'], c = colors[i], label = species[i])
    plt.ylabel("Sepal Length")
    plt.xlabel("Petal Width")
    plt.legend()

# %%
for i in range(3):
    x = df[df['Species'] == species[i]]
    plt.scatter(x['PetalLengthCm'], x['SepalWidthCm'], c = colors[i], label = species[i])
    plt.xlabel("Petal Length")
    plt.ylabel("Sepal Width")
    plt.legend()

# %%
#Regression plot

sns.regplot(x='SepalLengthCm', y='SepalWidthCm', data=df)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='SepalWidthCm'>

# %%
sns.regplot(x='SepalLengthCm', y='PetalLengthCm', data=df)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalLengthCm'>

# %%
sns.regplot(x='SepalLengthCm', y='PetalWidthCm', data=df)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='PetalWidthCm'>

# %%
sns.regplot(x='PetalLengthCm', y='PetalWidthCm', data=df)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='PetalWidthCm'>

# %% [markdown]
# # Correlation Matrix

# %%
df.corr()
# Out:
#                      Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Id             1.000000       0.716676     -0.397729       0.882747
# SepalLengthCm  0.716676       1.000000     -0.109369       0.871754
# SepalWidthCm  -0.397729      -0.109369      1.000000      -0.420516
# PetalLengthCm  0.882747       0.871754     -0.420516       1.000000
# PetalWidthCm   0.899759       0.817954     -0.356544       0.962757
# Species1       0.942830       0.782561     -0.419446       0.949043
#
#                PetalWidthCm  Species1
# Id                 0.899759  0.942830
# SepalLengthCm      0.817954  0.782561
# SepalWidthCm      -0.356544 -0.419446
# PetalLengthCm      0.962757  0.949043
# PetalWidthCm       1.000000  0.956464
# Species1           0.956464  1.000000

# %%
#heatmap of correlation matrix

corr = df.corr()
figure, axes = plt.subplots(figsize=(6,5))
sns.heatmap(corr, annot=True, ax = axes)
# Out:
# <AxesSubplot:>

# %%
df['SepalLengthCm'].corr(df['PetalLengthCm'])
# Out:
# 0.8717541573048718

# %% [markdown]
# # Model Training

# %%
from sklearn.model_selection import train_test_split

X = df.drop(columns=['Species'])
Y = df['Species']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.30)

# %%
# Logistic regression

from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
print("Accuracy: ", model.score(x_test,y_test) * 100)
# Out:
# Accuracy:  100.0

# %%
#statistics model

import statsmodels.formula.api as smapi

# %%
model1=smapi.ols(formula='SepalLengthCm~PetalLengthCm',data=df).fit()
print(model1.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:          SepalLengthCm   R-squared:                       0.760
# Model:                            OLS   Adj. R-squared:                  0.758
# Method:                 Least Squares   F-statistic:                     468.6
# Date:                Fri, 28 Jul 2023   Prob (F-statistic):           1.04e-47
# Time:                        22:07:01   Log-Likelihood:                -77.020
# No. Observations:                 150   AIC:                             158.0
# Df Residuals:                     148   BIC:                             164.1
# Df Model:                           1
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Intercept         4.3056      0.078     54.895      0.000       4.151       4.461
# PetalLengthCm     0.4091      0.019     21.646      0.000       0.372       0.446
# ==============================================================================
# Omnibus:                        0.212   Durbin-Watson:                   1.868
# Prob(Omnibus):                  0.899   Jarque-Bera (JB):                0.350
# Skew:                           0.070   Prob(JB):                        0.839
# Kurtosis:                       2.809   Cond. No.                         10.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
pred=model1.predict()
pred
# Out:
# array([4.87834171, 4.87834171, 4.83742912, 4.9192543 , 4.87834171,
#        5.00107948, 4.87834171, 4.9192543 , 4.87834171, 4.9192543 ,
#        4.9192543 , 4.96016689, 4.87834171, 4.75560394, 4.79651653,
#        4.9192543 , 4.83742912, 4.87834171, 5.00107948, 4.9192543 ,
#        5.00107948, 4.9192543 , 4.71469135, 5.00107948, 5.08290466,
#        4.96016689, 4.96016689, 4.9192543 , 4.87834171, 4.96016689,
#        4.96016689, 4.9192543 , 4.9192543 , 4.87834171, 4.9192543 ,
#        4.79651653, 4.83742912, 4.9192543 , 4.83742912, 4.9192543 ,
#        4.83742912, 4.83742912, 4.83742912, 4.96016689, 5.08290466,
#        4.87834171, 4.96016689, 4.87834171, 4.9192543 , 4.87834171,
#        6.22845718, 6.146632  , 6.31028236, 5.94206905, 6.18754459,
#        6.146632  , 6.22845718, 5.65568092, 6.18754459, 5.90115646,
#        5.7375061 , 6.02389423, 5.94206905, 6.22845718, 5.77841869,
#        6.10571941, 6.146632  , 5.98298164, 6.146632  , 5.90115646,
#        6.26936977, 5.94206905, 6.31028236, 6.22845718, 6.06480682,
#        6.10571941, 6.26936977, 6.35119495, 6.146632  , 5.7375061 ,
#        5.86024387, 5.81933128, 5.90115646, 6.39210754, 6.146632  ,
#        6.146632  , 6.22845718, 6.10571941, 5.98298164, 5.94206905,
#        6.10571941, 6.18754459, 5.94206905, 5.65568092, 6.02389423,
#        6.02389423, 6.02389423, 6.06480682, 5.53294315, 5.98298164,
#        6.76032085, 6.39210754, 6.71940826, 6.59667049, 6.67849567,
#        7.00579639, 6.146632  , 6.88305862, 6.67849567, 6.80123344,
#        6.39210754, 6.47393272, 6.5557579 , 6.35119495, 6.39210754,
#        6.47393272, 6.5557579 , 7.04670898, 7.12853416, 6.35119495,
#        6.63758308, 6.31028236, 7.04670898, 6.31028236, 6.63758308,
#        6.76032085, 6.26936977, 6.31028236, 6.59667049, 6.67849567,
#        6.80123344, 6.92397121, 6.59667049, 6.39210754, 6.59667049,
#        6.80123344, 6.59667049, 6.5557579 , 6.26936977, 6.51484531,
#        6.59667049, 6.39210754, 6.39210754, 6.71940826, 6.63758308,
#        6.43302013, 6.35119495, 6.43302013, 6.51484531, 6.39210754])

# %%
df['prediction']=pred
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species  Species1  prediction
# 0       Iris-setosa         0    4.878342
# 1       Iris-setosa         0    4.878342
# 2       Iris-setosa         0    4.837429
# 3       Iris-setosa         0    4.919254
# 4       Iris-setosa         0    4.878342
# ..              ...       ...         ...
# 145  Iris-virginica         2    6.433020
# 146  Iris-virginica         2    6.351195
# 147  Iris-virginica         2    6.433020
# 148  Iris-virginica         2    6.514845
# 149  Iris-virginica         2    6.392108
#
# [150 rows x 8 columns]

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species  \
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa
#
#    Species1  prediction
# 0         0    4.878342
# 1         0    4.878342
# 2         0    4.837429
# 3         0    4.919254
# 4         0    4.878342
